# %%
DATA_ROOT = "../SeoulTrafficData/data/"           
LOOKBACK = 20
MODE = "finetune"
EXISTING_MODEL_PATH = "../backend/models/traffic_lstm.h5"
OUTPUT_MODEL_PATH = "../backend/models/traffic_lstm.h5"    
OUTPUT_SCALER_PATH = "../backend/models/traffic_scaler.pkl" 
OUTPUT_X_PATH = "X_traffic_real.npy"
OUTPUT_Y_PATH = "y_traffic_real.npy"
USE_HOUR_FEATURE = False
